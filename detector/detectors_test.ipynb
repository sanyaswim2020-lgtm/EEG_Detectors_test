# %%
import os 
import matplotlib
import mne 
import numpy as np
mne.viz.set_browser_backend('qt')
# Out:
# Using qt as 2D backend.

# %%
interval = mne.io.read_raw_edf("/home/dmin/Code/EEG_Detectors_test/data/n3_intervals/sub_01/sub-02_ses-01_task-hfo_run-03_eeg.edf", preload=True)
# До фильтрации
if np.isnan(interval.get_data()).any():
    print("Внимание: в сырых данных обнаружены NaN!")
else:
    print('good')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 interval = mne.io.read_raw_edf("/home/dmin/Code/EEG_Detectors_test/data/n3_intervals/sub_01/sub-02_ses-01_task-hfo_run-03_eeg.edf", preload=True)
#       2 # До фильтрации
#       3 if np.isnan(interval.get_data()).any():
#
# File ~/Code/EEG_Detectors_test/detector_venv/lib/python3.12/site-packages/mne/io/edf/edf.py:2009, in read_raw_edf(input_fname, eog, misc, stim_channel, exclude, infer_types, include, preload, units, encoding, exclude_after_unique, verbose)
#    1888 @fill_doc
#    1889 def read_raw_edf(
#    1890     input_fname,
#    (...)   1902     verbose=None,
#    1903 ) -> RawEDF:
#    1904     """Reader function for EDF and EDF+ files.
#    1905
#    1906     Parameters
#    (...)   2007     However, this reader currently sets subseconds to 0 by default.
#    2008     """
# -> 2009     _check_args(input_fname, preload, "edf")
#    2011     return RawEDF(
#    2012         input_fname=input_fname,
#    2013         eog=eog,
#    (...)   2023         verbose=verbose,
#    2024     )
#
# File ~/Code/EEG_Detectors_test/detector_venv/lib/python3.12/site-packages/mne/io/edf/edf.py:1876, in _check_args(input_fname, preload, target_ext)
#    1874 def _check_args(input_fname, preload, target_ext):
#    1875     if not _file_like(input_fname):
# -> 1876         input_fname = _check_fname(fname=input_fname, overwrite="read", must_exist=True)
#    1877         ext = input_fname.suffix[1:].lower()
#    1879         if ext != target_ext:
#
# File <decorator-gen-0>:12, in _check_fname(fname, overwrite, must_exist, name, need_dir, check_bids_split, verbose)
#
# File ~/Code/EEG_Detectors_test/detector_venv/lib/python3.12/site-packages/mne/utils/check.py:302, in _check_fname(fname, overwrite, must_exist, name, need_dir, check_bids_split, verbose)
#     300             raise PermissionError(f"{name} does not have read permissions: {fname}")
#     301 elif must_exist:
# --> 302     raise FileNotFoundError(f'{name} does not exist: "{fname}"')
#     304 return fname
#
# FileNotFoundError: File does not exist: "/home/dmin/Code/EEG_Detectors_test/data/n3_intervals/sub_01/sub-02_ses-01_task-hfo_run-03_eeg.edf"

# %%
interval = mne.io.read_raw_fif("/home/dmin/Code/EEG_Detectors_test/data/filtered_data/sub_01_preprocessed_raw.fif", preload=True)
data = interval.get_data()
print(f"Максимум: {data.max()}, Минимум: {data.min()}, Среднее: {data.mean()}")
print(interval.get_channel_types())
interval.apply_function(lambda x: x * 1e-6)
interval.plot()
# Out:
# Opening raw data file /home/dmin/Code/EEG_Detectors_test/data/filtered_data/sub_01_preprocessed_raw.fif...
# Isotrak not found
#     Range : 0 ... 599999 =      0.000 ...   300.000 secs
# Ready.
# Reading 0 ... 599999  =      0.000 ...   300.000 secs...
# Максимум: 42.78512954711914, Минимум: -32.72397232055664, Среднее: 1.0414244102231315e-05
# ['eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg']
# Extracting EDF parameters from /home/dmin/Code/EEG_Detectors_test/data/n3_intervals/sub_01/sub-01_ses-01_task-hfo_run-01_eeg.edf...
# Setting channel info structure...
# Creating raw.info structure...

# %%
n3_interval = mne.io.read_raw_edf("/home/dmin/Code/EEG_Detectors_test/data/n3_intervals/sub_01/sub-01_ses-01_task-hfo_run-01_eeg.edf", preload = True)
data_n3 = n3_interval.get_data()
print(f"Максимум: {data_n3.max()}, Минимум: {data_n3.min()}, Среднее: {data_n3.mean()}")
print(n3_interval.get_channel_types())
n3_interval.apply_function(lambda x: x * 1e-6)
n3_interval.plot()
# Out:
# Extracting EDF parameters from /home/dmin/Code/EEG_Detectors_test/data/n3_intervals/sub_01/sub-01_ses-01_task-hfo_run-01_eeg.edf...
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 599999  =      0.000 ...   300.000 secs...
# Максимум: 694.4886000000001, Минимум: -620.811, Среднее: 8.729286060776362e-05
# ['eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg']

# %%
def preprocess_file(path_to_edf_file, LOW_FREQS, HIGH_FREQS):
    """
    path_to_edf_file - путь к целовому фрагменту сигнала
    LOW_FREQS - нижний порог фильтрации
    HIGH_FREQS - верхний порог фильтрации
    """
    interval = mne.io.read_raw_edf(path_to_edf_file, preload=True)

    interval.pick_types(eeg=True, meg=False, stim=False, eog=False, ecg=False)

    interval.notch_filter(freqs=50)

    interval.filter(l_freq=LOW_FREQS, h_freq=HIGH_FREQS)

    return interval 


def main(path, sub_num, low_freqs, high_freqs):
    interval = preprocess_file(path, low_freqs, high_freqs)
    interval.save(f'/home/dmin/Code/EEG_Detectors_test/data/n3_intervals/sub_{sub_num}/sub-{sub_num}_eeg.fif', overwrite=True, fmt='single')
    interval.plot(scalings=dict(eeg=100e-6), clipping='clamp')



if __name__ == '__main__':
    path = "/home/dmin/Code/EEG_Detectors_test/data/n3_intervals/sub_01/sub-01_ses-01_task-hfo_run-01_eeg.edf"
    sub_num = '01' # добавить автоматическое определение номера испытуемого
    LOW_FREQS = 80
    HIGH_FREQS = 500
    main(path, sub_num, LOW_FREQS, HIGH_FREQS)
# Out:
# Extracting EDF parameters from /home/dmin/Code/EEG_Detectors_test/data/n3_intervals/sub_01/sub-01_ses-01_task-hfo_run-01_eeg.edf...
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 599999  =      0.000 ...   300.000 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 13201 samples (6.601 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 500.00 Hz
# - Upper transition bandwidth: 125.00 Hz (-6 dB cutoff frequency: 562.50 Hz)
# - Filter length: 331 samples (0.166 s)
#
# Overwriting existing file.
# Writing /home/dmin/Code/EEG_Detectors_test/data/n3_intervals/sub_01/sub-01_eeg.fif
# Overwriting existing file.
# Closing /home/dmin/Code/EEG_Detectors_test/data/n3_intervals/sub_01/sub-01_eeg.fif
# [done]

# %%
data = raw_fi

# %%
# Разделям диапазон hfo на ripples и fast ripples для применения Hilbert's envelope 
# (соблюдение теоремы Бедросяна)
LOW_FREQS_ripples = 80
HIGH_FREQS_ripples = 250
LOW_FREQS_fast_ripples = 250
HIGH_FREQS_fast_ripples = 500

interval_ripples = interval.copy().filter(l_freq=LOW_FREQS_ripples, h_freq=HIGH_FREQS_ripples)
interval_fast_ripples = interval.copy().filter(l_freq=LOW_FREQS_fast_ripples, h_freq=HIGH_FREQS_fast_ripples)

hilbert_ripples = interval_ripples.apply_hilbert(envelope=True)
hilbert_fast_ripples = interval_fast_ripples.apply_hilbert(envelope=True)

hilbert_ripples.plot()
hilbert_fast_ripples.plot()
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 80 - 2.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 80.00
# - Lower transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 70.00 Hz)
# - Upper passband edge: 250.00 Hz
# - Upper transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 281.25 Hz)
# - Filter length: 331 samples (0.166 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 2.5e+02 - 5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 250.00
# - Lower transition bandwidth: 62.50 Hz (-6 dB cutoff frequency: 218.75 Hz)
# - Upper passband edge: 500.00 Hz
# - Upper transition bandwidth: 125.00 Hz (-6 dB cutoff frequency: 562.50 Hz)
# - Filter length: 107 samples (0.053 s)
